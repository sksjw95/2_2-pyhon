# %% [markdown]
# <a href="https://colab.research.google.com/github/sksjw95/2_2-pyhon/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

nex8 = pd.read_csv("/content/ex8-1.csv",header = 0)
nex8.head()
nex8.head(3)
nex8.tail(3)
type(nex8)
nex8.shape
# Out:
# (10, 5)

# %%
import pandas as pd
nex8_2 = pd.read_excel("/content/nex8-1.xlsx",header = 0, sheet_name = 0)
nex8_2.head(3)
nex8_2["age"]
nex8_2.age
cols = ['sex','age','edu','salary']
nex8_2[cols]
nex8_2.iloc[:,1:]
nex8_2.head(2)
nex8_2.iloc[:,1:]
# Out:
#    id sex  age     edu  salary
# 0   1   m   21    high     150
# 1   2   f   22  middle     100
